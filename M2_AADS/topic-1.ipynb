# %% [markdown]
# # Python Algorithms And Data Structures - Topic 1
#
# - Тест 1. Основные понятия теории алгоритмов
# - Тест 2. Анализ работы алгоритмов
#
# ---
#
# Примеры написаны на Python 3.11

# %% [markdown]
# # Тестовая часть
# ---
#
# ## Тест 1. Основные понятия теории алгоритмов
#
# ### Вопрос 1.
#
# Является ли следующее определение понятия «алгоритм» формальным: алгоритм — это любая корректно определённая вычислительная процедура, на вход которой подается некоторая величина или набор величин и результатом выполнения которой является выходная величина или набор значений.
#
# - Верно
# - Неверно ✅
#
# ### Вопрос 2.
#
# Какие фамилии связаны с попытками формализовать понятия алгоритма:
#
# - Рассел
# - Пост ✅
# - Форд
# - Тьюринг ✅
#
# ### Вопрос 3.
#
# Где для формализации понятия алгоритма используется бесконечная лента:
#
# - Нормальном алгорифм Маркова
# - Рекурсивные функции
# - Лямбда-исчисление
# - Машина Тьюринга ✅
#
# ### Вопрос 4.
#
# Какими из этих свойств должен обладать алгоритм:
#
# - Формальность ✅
# - Конечность ✅
# - Универсальность ✅
# - Дискретность ✅
#
# ### Вопрос 5.
#
# В каких случаях говорят о вычислительное процедуре, а не об алгоритме:
#
# - Последовательность шагов никогда не заканчивается ✅
# - Последовательность шагов не детерминирована
# - Приведённая последовательность шагов не определена формально
#
# ### Вопрос 6.
#
# Алгоритм должен обладать свойством универсальностью, что означает возможностью применить его к различным входным данным.
# К каким данным может быть применён алгоритм двоичного поиска:
#
# - Геометрические фигуры
# - Числа ✅
# - Математические функции (sin, cos, log и пр.)
# - Строки ✅
#
# ### Вопрос 7.
#
# Алгоритм можно описать следующим образом:
#
# - Словесно ✅
# - Блок-схемой ✅
# - На языке Python ✅
#
# ### Вопрос 8.
#
# Блок-схемы согласно ГОСТ 19.701-90 содержит следующие элементы:
#
# - Прямоугольник ✅
# - Звезда
# - Точка
# - Ромб
# - Параллелепипед
#
# ## Тест 2. Основные понятия теории алгоритмов
#
# ### Вопрос 1.
#
# В алгоритме 2 вложенных цикла: внешний на 30 итераций, а внутренний на 10. Какое общее количество инструкций будет выполнено?
#
# - 30
# - 450
# - 10
# - 300 ✅
# - 100
#
# ### Вопрос 2.
#
# Существуют 2 алгоритма: первый работает за n^2, второй за 10n. При каких значениях n первый алгоритм будет работать быстрее второго.
#
# - 12
# - 25
# - 8 ✅
# - 3 ✅
# - 20
#
# ### Вопрос 3.
#
# Как называют рост функции при зависимости от числа n выраженной формулой log n?
#
# - Линейный
# - Квазилинейный
# - Факториальный
# - Константный
# - Экспоненциальный
# - Квадратичный
# - Полиномиальный
# - Логарифмический ✅
#
# ### Вопрос 4.
#
# Лучшим времени работы алгоритма, который зависит от n, является:
#
# - То, которое будет иметь лучшее время работы при всех значениях n
# - То, которое будет при наименьшем значении n
# - То, которое будет иметь лучшее время работы при определённых n  ✅
# - То, которое будет при наибольшем значении n
#
# ### Вопрос 5.
#
# Для анализа работы алгоритма в среднем используют:
#
# - Среднее арифметическое от всех случаев
# - Среднее от лучшего и худшего случа
# - Математическое ожидание случайной величины ✅
#
# ### Вопрос 6.
#
# Как будет записана асимптотическая верхняя оценка, если алгоритм выражен зависимостью: T(n) = 12nlog n + 19n - 10?
#
# - O(10)
# - O(19n)
# - O(n log n) ✅
#
# ### Вопрос 7.
#
# Буквой О-большое греческого алфавита обозначают асимптотически:
#
# - нижнюю границу
# - верхнюю границу ✅
#
# ### Вопрос 8.
#
# Обозначение Θ(g(n)) обозначает:
#
# - Множество таких функций, что для некоторых констант с1 и c2 эти функции будут между c1 * g(n) и c2 * g(n) ✅
# - Оценку в среднем случае
# - Временную сложность работы алгоритма
#
# ### Вопрос 9.
#
# Рекурсивные алгоритмы обязательно содержат следующие шаги:
#
# - Комбинирование подзадач в решение ✅
# - Разделение задачи на подзадачи ✅
# - Рекурсивная обработка задачи ✅
#
# ### Вопрос 10.
#
# Как записывается рекуррентное соотношение в общем виде?
#
# - T(n) = T(n) / 2
# - T(n) = aT(n/b) + f(n) ✅
# - T(n) = T(n) + f(n)
#
# ### Вопрос 11.
#
# Для алгоритма с оценкой O(n log n) можно утверждать, что функция T(n) может быть:
#
# - линейной ✅
# - не более чем c * n log n для некоторого c ✅
# - не менее n^2
#
# ### Вопрос 12.
#
# Для алгоритма с оценкой Ω(n) можно утверждать, что функция T(n) может быть:
#
# - не менее n^2  ✅
# - линейной ✅
# - не более чем c * log n для некоторого c
#
# # Практическая часть
# ---
#
# ...

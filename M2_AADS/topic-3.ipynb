# %% [markdown]
# # Python Algorithms And Data Structures - Topic 3
#
# - Практическое задание: двоичная сортировка вставками
# - Тест 4. Задачи сортировки
#
# ---
#
# Примеры написаны на Python 3.11

# %% [markdown]
# # Тестовая часть
# ---

# %% [markdown]
# ## Тест 4. Задачи сортировки
#
# ### Вопрос 1. Устойчивыми называют сортировки, которые:
#
# - Работают гарантировано за O(n log n)
# - Не используют дополнительную память
# - Не меняют местами 2 одинаковых элемента в ходе своей работы ✅
#
# ### Вопрос 2. Сортировки, не использующие дополнительной памяти называются:
#
# - Сортировкой на месте (in-place) ✅
# - Местной сортировкой
# - Сортировкой без памяти
#
# ### Вопрос 3. В том случае, если сортировка работает лучше при определённых обстоятельствах, эту сортировку называют:
#
# - Адаптивной ✅
# - Конкурентной
# - Неустойчивой
#
# ### Вопрос 4. Сортировка выборкой работает путём:
#
# - Выбором наименьшего элемента и перемещения его в отсортированную часть ✅
# - Перемешивания всех элементов и проверкой результата на отсортированность
# - Обменом двух соседних элементов местами в зависимости от их порядка
#
# ### Вопрос 5. Временная сложность сортировки выборкой составляет:
#
# - O(n^2) ✅
# - O(log n)
# - O(n)
#
# ### Вопрос 6. Сортировка выборкой является адаптивной:
#
# - Нет ✅
# - Да
#
# ### Вопрос 7. Сортировка пузырьком работает путём:
#
# - Переносом меньшего элемента влево, пока оно не займёт правильное место
# - Переносом большего элемента в конец списка
# - Обмена соседних элементов в том случае, если они расположены неверно ✅
#
# ### Вопрос 8. Сортировка пузырьком является адаптивной:
#
# - Да, если есть условие, проверяющее, что ни один элемент не был перемещён ✅
# - Да при любой реализации
# - Нет
#
# ### Вопрос 9. Временная сложность сортировки пузырьком является:
#
# - O(n^2) ✅
# - O(log n)
# - O(n^3)
#
# ### Вопрос 10. Что нужно добавить в сортировку пузырьком, чтобы она работала за линейное время в лучшем случае?
#
# - Рекурсивный вызов сортировки
# - Проверку после внутреннего цикла, что ни один из элементов не был перемещён ✅
# - Ничего, она и так работает за линейное время
#
# ### Вопрос 11. Сортировка вставками работает путём:
#
# - Случайного перемешивания элементов списка
# - Поиска наименьшего элемента и переносом его в отсортированную часть
# - Перемещения текущего элемента в отсортированной части в правильное место ✅
#
# ### Вопрос 12. Временная сложность работы алгоритма сортировки вставками состовляет:
#
# - O(n^2) ✅
# - O(n log n)
# - O(n) для лучшего случая ✅
#
# ### Вопрос 13. Сортировка вставками является адаптивной
#
# - Нет
# - Да ✅
#
# ### Вопрос 14. Сортировка вставками является in-place сортировкой:
#
# - Нет
# - Да ✅
#
# ### Вопрос 15. Сортировка выборкой является in-place сортировкой:
#
# - Да ✅
# - Нет
#
# ### Вопрос 16. Сортировка пузырьком является in-place сортировкой:
#
# - Нет
# - Да ✅
#
# ### Вопрос 17. Сортировка пузырьком является устойчивой сортировкой:
#
# - Нет
# - Да ✅
#
# ### Вопрос 18. Сортировка вставками является устойчивой сортировкой:
#
# - Да ✅
# - Нет
#
# ### Вопрос 19. Какие сортировки называются эффективными?
#
# - Сортировки, работающие в среднем за O(n log n) ✅
# - Адаптивные сортировки
# - Сортировки не использующие сравнение
#
# ### Вопрос 20. Какой принцип используется в большинстве эффективных сортировок?
#
# - Соединяй и перемещай
# - Добавляй и удаляй
# - Разделяй и властвуй ✅
#
# ### Вопрос 21. На сколько частей разбивается исходный массив в сортировке слияниями:
#
# - 2 ✅
# - 10
# - log(n)
#
# ### Вопрос 22. В чём заключается суть операции слияния?
#
# - В объединении двух отсортированных массивов путём добавления второго к первому
# - В объединении двух неотсортировнных массивов в один путём их конкатенации
# - В объединении двух отсортированных массивов в один отсортированный ✅
#
# ### Вопрос 23. Временная сложность сортировки слиянием в худшем случае является:
#
# - O(n^2)
# - O(n log n) ✅
# - O(n)
#
# ### Вопрос 24. Для работы алгоритма сортировки слиянием требуется использовать дополнительную память:
#
# - Да ✅
# - Нет
#
# ### Вопрос 25. Сортировка слияниями является устойчивой:
#
# - Нет
# - Да ✅
#
# ### Вопрос 26. Быстрой сортировке требуется дополнительную память для работы:
#
# - Нет ✅
# - Да
#
# ### Вопрос 27. Основной принцип работы быстрой сортировки заключается в:
#
# - Перемещении элемента последовательно справа налево
# - Разбиении массива на два подмассива, где в одном элементы будут меньше некоторого значения, а во втором больше ✅
# - Объединении подмассивов в один больший массив
#
# ### Вопрос 28. Быстрая сортировка в среднем работает за:
#
# - O(n log n) ✅
# - O(n)
# - O(n^2)
#
# ### Вопрос 29. Быстрая сортировка в худшем случае работает за:
#
# - O(n^2) ✅
# - O(n)
# - O(n log n)
#
# ### Вопрос 30. На что влияет выбор опорного элемента в быстрой сортировке?
#
# - Ни на что не влияет
# - Плохой выбор элемента может ухудшить время работы ✅
# - Хороший выбор элемента уменьшает количество необходимой дополнительной памяти

# %% [markdown]
# # Практическая часть
# ---

# %% [markdown]
# ## Практическое задание: двоичная сортировка вставками

# %% [markdown]
# В отличии от классического алгоритма внутренний цикл, который перемещает элемент к нужной позиции, заменяется на 2 операции:
# - Поиск двоичным поиском места, куда элемент должен попасть
# - Сдвиг всего массива начиная с этого места на 1 элемент и последующая запись текущего элемента на это место
#
# Теоретическая оценка времени работать будет хуже в сравнении с классическим вариантом, но, когда операция сдвига участка массива может быть выполнена за небольшое время (меньшее, чем если бы все элементы просто сдвигались по очереди, как это выполнено в классическом алгоритме), то этот алгоритм работает в общем лучше.
#
# ---
#
# В случае, когда необходимо выполнить поиск в уже упорядоченном списке, можно использовать двоичный поиск, алгоритм которого сводится к такой последовательности:
#
# - Для заданного промежутка в массиве (изначально он равен всему массиву, то есть начало — 0, конец — длина массива) найти позиции элемента по середине как «Средний элемент =- (начало + конец) / 2». Деление должно быть целочисленным.
# - Сравить элемент по вычисленному индексу с ключом. Если они равны, то вернуть текущий индекс
# - Если элементы не равны и ключ меньше элемента по середине, то выставить «конец = середина - 1» и рекурсивно вызвать поиск
# - Если элементы не равны и ключ больше элемента по середине, то выставить «начало = середина + 1» и рекурсивно вызвать поиск
#
# Для корректной работы также необходимо в самом начале функции проверить, что индекс начала больше индекса конца. Если это не так, то это будет значить, что элемент не может быть найден. Такая ситуация возникает и в процессе рекурсивного вызова. При этом индекс начала интрепретируется как индекс, куда нужно добавить ключ, чтобы последовательность была верной. Чтобы её отличать от ситуации когда элемент всё-таки найден этот индекс берут с отрицательным знаком и вычитаются единицу. Таким образом можно, результат работы алгоритма должен быть:
#
# ```py
# arr = [1, 3, 5]
# print(binary_search(arr, 1, 0, len(arr) - 1) == 0)
# print(binary_search(arr, 3, 0, len(arr) - 1) == 1)
# print(binary_search(arr, 5, 0, len(arr) - 1) == 2)
# print(binary_search(arr, 0, 0, len(arr) - 1) == -0 - 1)
# print(binary_search(arr, 2, 0, len(arr) - 1) == -1 - 1)
# print(binary_search(arr, 4, 0, len(arr) - 1) == -2 - 1)
# print(binary_search(arr, 6, 0, len(arr) - 1) == -3 - 1)
# ```
#
# Где процедура binary_search имеет следуещее описание:
#
# ```py
# def binary_search(x, key, start, end)
# ```
#
# `x` — упорядоченный список элементов `key` — искомый элемент `start` — индекс начала `end` — индекс конца
# Процедура возвращает индекс элемента в списке или индекс взятый с отрицательным знаком - 1 позиции, где этот элемент должен был бы находиться

# %%
def binary_search(x, key, start, end):
    mid = (start + end) // 2
    if start > end:
        return -mid - 2
    if x[mid] > key:
        return binary_search(x, key, start, mid - 1)
    elif x[mid] < key:
        return binary_search(x, key, mid + 1, end)
    else:
        return mid

# Solution Test

arr = [1, 3, 5]

print(binary_search(arr, 1, 0, len(arr) - 1) == 0)
print(binary_search(arr, 3, 0, len(arr) - 1) == 1)
print(binary_search(arr, 5, 0, len(arr) - 1) == 2)
print(binary_search(arr, 0, 0, len(arr) - 1) == -0 - 1)
print(binary_search(arr, 2, 0, len(arr) - 1) == -1 - 1)
print(binary_search(arr, 4, 0, len(arr) - 1) == -2 - 1)
print(binary_search(arr, 6, 0, len(arr) - 1) == -3 - 1)

# %% [markdown]
# Чтобы переместить элемент в списке можно последовательно обменивать его с соседом. Именно этот подход реализован в классическом алгоритме сортировки вставками. Другой способ — это каким-либо образом сдвинуть несколько значений одновременно на 1 элемент и на освободившееся место добавить нужный элемент.
#
# Для реализации перемещения элемент в списке можно просто выполнить 2 операции:
# - Удалить элемент с его позиции из списка
# - Добавить элемент на новую позицию в списке
#
# Таким образом необходимо реализовать метод со следующим описанием:
# ```py
# def swap(x, old, new)
# ```
#
# Где `x` — массив, `old` — индекс элемента, который необходимо переместить, `new` — позиция в списке, куда элемент нужно переместить
#
# ```py
# swap([1, 2, 3], 1, 0) # [2, 1, 3]
# swap([1, 2, 3], 2, 0) # [3, 1, 2]
# ```

# %%
def swap(x, old, new):
    t = x[old]
    while old != new:        
        x[old] = x[old - 1]
        old -= 1
    x[new] = t
    return x

# Solution Test

print(swap([1, 2, 3], 1, 0)) # [2, 1, 3]
print(swap([1, 2, 3], 2, 0)) # [3, 1, 2]

# %% [markdown]
# Алгоритм двоичной сортировки вставками формулируется следующим образом:
#
# Пока не пройдены все элементы списка от начала к концу взять следующий элемент в списке и с помощью бинарного поиска найти ему место в списке из элементов, стоящих до него, после чего переместить этот элемент на это место.
#
# Реализуйте этот алгоритм, имеющий следующее описание:
# ```py
# def sort(x)
# ```
# где `x` — сортируемый список.
#
# Используйте процедуры `binary_search` и `swap` из предыдущих заданий при реализации сортировки и не забудьте добавить их в ответ, чтобы ответы были приняты. Тест проверяет, что будет отсортирован исходный список x (его можно изменить с помощью методов для работы со списками, такими как `insert`, `pop` и др.)

# %%
def binary_search(x, key, start, end):
    mid = (start + end) // 2
    if start > end:
        return -mid - 2
    if x[mid] > key:
        return binary_search(x, key, start, mid - 1)
    elif x[mid] < key:
        return binary_search(x, key, mid + 1, end)
    else:
        return mid

def swap(x, old, new):
    t = x[old]
    while old != new:        
        x[old] = x[old - 1]
        old -= 1
    x[new] = t
    return x

def sort(x):
    n = len(x)
    for i in range(1, n):
        j = i
        v = binary_search(x, x[j], 0, i)
        swap(x, j, (-v - 1) if v < 0 else v)

# Solution Test

x = [1, 6, 2, 3, 7, 8, 4, 5, 9]
sort(x)
print(x)
